# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataframe = pd.read_excel('/content/drive/MyDrive/ArquivosColab/2023_ModificadoAula.xlsx')

# %%
dados_basicos = dataframe.loc[:, ['CodigoMEC', 'Nome', 'TipoEscola']]

# %%
dataframe.groupby(['Nome'])['TipoEscola'].mean()
# Out:
# Nome
#  Centro Federal De Educação Tecnológica Celso Suckow Da Fonseca - Cefet/rj    1.0
#  Colégio E Curso Progressão Niterói                                           2.0
#  Colégio Monteiro Lobato França                                               2.0
#  Dom Jacson Damasceno Rodrigues                                               1.0
#  Em Dr. Jair Mendes De Barros                                                 1.0
#                                                                              ...
# Zeta Centro Educacional Buritama                                              2.0
# Zeta Sistema De Ensino De Birigui                                             2.0
# Zip Zap Colegio                                                               2.0
# Zulmira Campos Professora                                                     1.0
# Álvaro De Araújo Carneiro                                                     1.0
# Name: TipoEscola, Length: 4569, dtype: float64

# %%
dataframe.groupby(['Nome','CodigoMEC'])[['TipoEscola']].sum()
# Out:
#                                                               TipoEscola
# Nome                                               CodigoMEC
#  Centro Federal De Educação Tecnológica Celso S... 33067643            1
#  Colégio E Curso Progressão Niterói                33176787            2
#  Colégio Monteiro Lobato França                    35130680            2
#  Dom Jacson Damasceno Rodrigues                    13076841            1
#  Em Dr. Jair Mendes De Barros                      35232048            1
# ...                                                                  ...
# Zeta Centro Educacional Buritama                   35802001            2
# Zeta Sistema De Ensino De Birigui                  35100419            2
# Zip Zap Colegio                                    35172662            2
# Zulmira Campos Professora                          35046760            1
# Álvaro De Araújo Carneiro                          23099402            2
#
# [4760 rows x 1 columns]

# %%
dados_basicos.sort_values(['Nome'], ascending = True, inplace = True)

# %%
dados_basicos.head()
# Out:
#       CodigoMEC                                               Nome  TipoEscola
# 1959   33067643   Centro Federal De Educação Tecnológica Celso ...           1
# 3227   33176787                 Colégio E Curso Progressão Niterói           2
# 3994   35130680                     Colégio Monteiro Lobato França           2
# 2816   13076841                     Dom Jacson Damasceno Rodrigues           1
# 336    35232048                       Em Dr. Jair Mendes De Barros           1

# %%
dados_basicos.sort_values(['Nome'], ascending = False, inplace = True)
# Out:
#       CodigoMEC                                               Nome  TipoEscola
# 2473   23099402                          Álvaro De Araújo Carneiro           1
# 2474   23099402                          Álvaro De Araújo Carneiro           1
# 5139   35046760                          Zulmira Campos Professora           1
# 4787   35172662                                    Zip Zap Colegio           2
# 3519   35100419                  Zeta Sistema De Ensino De Birigui           2
# ...         ...                                                ...         ...
# 336    35232048                       Em Dr. Jair Mendes De Barros           1
# 2816   13076841                     Dom Jacson Damasceno Rodrigues           1
# 3994   35130680                     Colégio Monteiro Lobato França           2
# 3227   33176787                 Colégio E Curso Progressão Niterói           2
# 1959   33067643   Centro Federal De Educação Tecnológica Celso ...           1
#
# [5273 rows x 3 columns]

# %%
dados_basicos.sort_values(['Nome', 'CodigoMEC'], ascending = True, inplace = True)

# %%
dados_basicos.head()
# Out:
#       CodigoMEC                                               Nome  TipoEscola
# 1959   33067643   Centro Federal De Educação Tecnológica Celso ...           1
# 3227   33176787                 Colégio E Curso Progressão Niterói           2
# 3994   35130680                     Colégio Monteiro Lobato França           2
# 2816   13076841                     Dom Jacson Damasceno Rodrigues           1
# 336    35232048                       Em Dr. Jair Mendes De Barros           1
