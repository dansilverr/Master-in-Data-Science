# %%
import pandas as pd

# %%
base = {
        'Fiat': ['Palio', 'Uno', '147', 'Argos'],
        'Chevrolet': ['Kadet', 'Celta', 'Meriva', 'Onix'],
        'VolksWagen': ['Gol', 'Saveiro', 'T-Cross', 'Virtus'],
        'Ford': ['Ka', 'Fiesta', 'Focus', 'EcoSport']
     
    }

# %%
dataframe = pd.DataFrame(base)

# %%
dataframe.head()
# Out:
#     Fiat Chevrolet VolksWagen      Ford
# 0  Palio     Kadet        Gol        Ka
# 1    Uno     Celta    Saveiro    Fiesta
# 2    147    Meriva    T-Cross     Focus
# 3  Argos      Onix     Virtus  EcoSport

# %%
dataframe.replace('T-Cross', 'Santana', inplace = True)

# %%
dataframe.head()
# Out:
#     Fiat Chevrolet VolksWagen      Ford
# 0  Palio     Kadet        Gol        Ka
# 1    Uno     Celta    Saveiro    Fiesta
# 2    147    Meriva    Santana     Focus
# 3  Argos      Onix     Virtus  EcoSport

# %%
dataframe.replace(['Santana', 'Virtus', 'Saveiro'], 'T-Cross')
# Out:
#     Fiat Chevrolet VolksWagen      Ford
# 0  Palio     Kadet        Gol        Ka
# 1    Uno     Celta    T-Cross    Fiesta
# 2    147    Meriva    T-Cross     Focus
# 3  Argos      Onix    T-Cross  EcoSport

# %%
dataframe['Fiat'].replace('147', 'Bravo', inplace = True)

# %%
dataframe.head()
# Out:
#     Fiat Chevrolet VolksWagen      Ford
# 0  Palio     Kadet        Gol        Ka
# 1    Uno     Celta    Saveiro    Fiesta
# 2  Bravo    Meriva    Santana     Focus
# 3  Argos      Onix     Virtus  EcoSport

# %%
dataframe['Fiat'] = dataframe['Fiat'].replace('Bravo', 'Punto')

# %%
dataframe.head()
# Out:
#     Fiat Chevrolet VolksWagen      Ford
# 0  Palio     Kadet        Gol        Ka
# 1    Uno     Celta    Saveiro    Fiesta
# 2  Punto    Meriva    Santana     Focus
# 3  Argos      Onix     Virtus  EcoSport

# %%
dataframe['Chevrolet'].replace({'Meriva': 'Prisma', 'Kadet': 'Corsa'}, inplace = True)

# %%
dataframe.head()
# Out:
#     Fiat Chevrolet VolksWagen      Ford
# 0  Palio     Corsa        Gol        Ka
# 1    Uno     Celta    Saveiro    Fiesta
# 2  Punto    Prisma    Santana     Focus
# 3  Argos      Onix     Virtus  EcoSport
