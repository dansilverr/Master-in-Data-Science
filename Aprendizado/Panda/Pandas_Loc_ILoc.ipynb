# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe = pd.read_excel('/content/drive/MyDrive/ArquivosColab/2023_ModificadoAula.xlsx')

# %%
dataframe.loc[:]
# Out:
#       IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 0           14833         4           2   23245980
# 1           15411         6           2   23564130
# 2           17568         7           1   33062706
# 3           14297         8           2   23025255
# 4           15363        11           2   35108339
# ...           ...       ...         ...        ...
# 5268        20451      9320           1   26101793
# 5269        20454      9321           2   25200801
# 5270        20455      9322           1   31134791
# 5271        20457      9323           1   25015729
# 5272        20458      9324           1   23273950
#
#                                                    Nome            CNPJ  \
# 0                              Colégio Antares - Papicu   7250616000240
# 1     Alegria Do Saber Centro De Educacao Infantil E...  13207350000175
# 2                        Colégio Pedro Ii Campus Centro  42414284000706
# ...

# %%
dataframe.loc[:,['Nome']]
# Out:
#                                                    Nome
# 0                              Colégio Antares - Papicu
# 1     Alegria Do Saber Centro De Educacao Infantil E...
# 2                        Colégio Pedro Ii Campus Centro
# 3                                Colégio Luciano Feijão
# 4                                  Colégio Santa Mônica
# ...                                                 ...
# 5268        Escola Municipal Jayme De Castro Montenegro
# 5269                Valba Rossana Duarte Do Rego Farias
# 5270                                   Ee Evandro Avila
# 5271                        Emef Manuel Alves De Farias
# 5272  E.e.b. Professora Hilda Ponciano De Oliveira Lima
#
# [5273 rows x 1 columns]

# %%
dataframe.loc[:,['Nome', 'CodigoMEC']]
# Out:
#                                                    Nome  CodigoMEC
# 0                              Colégio Antares - Papicu   23245980
# 1     Alegria Do Saber Centro De Educacao Infantil E...   23564130
# 2                        Colégio Pedro Ii Campus Centro   33062706
# 3                                Colégio Luciano Feijão   23025255
# 4                                  Colégio Santa Mônica   35108339
# ...                                                 ...        ...
# 5268        Escola Municipal Jayme De Castro Montenegro   26101793
# 5269                Valba Rossana Duarte Do Rego Farias   25200801
# 5270                                   Ee Evandro Avila   31134791
# 5271                        Emef Manuel Alves De Farias   25015729
# 5272  E.e.b. Professora Hilda Ponciano De Oliveira Lima   23273950
#
# [5273 rows x 2 columns]

# %%
dataframe.loc[2:5]
# Out:
#    IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 2        17568         7           1   33062706
# 3        14297         8           2   23025255
# 4        15363        11           2   35108339
# 5        16099        12           2   25115260
#
#                                  Nome            CNPJ InscricaoEstadual  \
# 2      Colégio Pedro Ii Campus Centro  42414284000706               NaN
# 3              Colégio Luciano Feijão   9533217000212               NaN
# 4                Colégio Santa Mônica  52566411000142               NaN
# 5  Século Colégio E Curso - Bancários   1573657000100               NaN
#
#                                    Endereco Numero Complemento  ...  \
# 2                 Avenida Marechal Floriano     80         NaN  ...
# 3                          AVENIDA DOM JOSÉ    325         NaN  ...
# 4                              Rua São João    141         NaN  ...
# 5  Rua Radialista Antonio Assunção de Jesus     89         NaN  ...
#
# ...

# %%
dataframe.loc[[2]]
# Out:
#    IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 2        17568         7           1   33062706
#
#                              Nome            CNPJ InscricaoEstadual  \
# 2  Colégio Pedro Ii Campus Centro  42414284000706               NaN
#
#                     Endereco Numero Complemento  ... UFResponsavel  \
# 2  Avenida Marechal Floriano     80         NaN  ...            RJ
#
#   CEPResponsavel  NomeResponsavelConcurso      EmailResponsavelConcurso  \
# 2       20080001  Anderson Reis De Vargas  anderson.vargas.1@cp2.edu.br
#
#    LoginEscola PacoteInscricao StatusInscricao DataCriacaoInscricao  \
# 2    CP2CENTRO               1               2                False
#
#   Unnamed: 37 Unnamed: 38
# 2  26/02/2023       False
#
# [1 rows x 39 columns]

# %%
dataframe.loc[2:5, ['CodigoMEC','Nome']]
# Out:
#    CodigoMEC                                Nome
# 2   33062706      Colégio Pedro Ii Campus Centro
# 3   23025255              Colégio Luciano Feijão
# 4   35108339                Colégio Santa Mônica
# 5   25115260  Século Colégio E Curso - Bancários

# %%
dataframe.loc[dataframe["TipoEscola"]== 2]
# Out:
#       IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 0           14833         4           2   23245980
# 1           15411         6           2   23564130
# 3           14297         8           2   23025255
# 4           15363        11           2   35108339
# 5           16099        12           2   25115260
# ...           ...       ...         ...        ...
# 5260        20440      9312           2   35191577
# 5263        20444      9315           2   35007124
# 5264        20445      9316           2   35007524
# 5267        20449      9319           2   35007148
# 5269        20454      9321           2   25200801
#
#                                                    Nome            CNPJ  \
# 0                              Colégio Antares - Papicu   7250616000240
# 1     Alegria Do Saber Centro De Educacao Infantil E...  13207350000175
# 3                                Colégio Luciano Feijão   9533217000212
# ...

# %%
dataframe.loc[(dataframe["TipoEscola"] == 2) & (dataframe['UFResponsavel'] == 'SP')]
# Out:
#       IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 4           15363        11           2   35108339
# 10          15546        19           2   35165578
# 11          14130        20           2   35138769
# 12          14136        20           2   35138769
# 18          15274        29           2   35366353
# ...           ...       ...         ...        ...
# 5244        20403      9296           2   35194273
# 5260        20440      9312           2   35191577
# 5263        20444      9315           2   35007124
# 5264        20445      9316           2   35007524
# 5267        20449      9319           2   35007148
#
#                                               Nome            CNPJ  \
# 4                             Colégio Santa Mônica  52566411000142
# 10                                  Anglo Sorocaba   6988267000115
# 11                                  Colégio Asther   7442284000115
# 12                                  Colégio Asther   7442284000115
# ...

# %%
dataframe.loc[(dataframe["TipoEscola"] == 2) | (dataframe['UFResponsavel'] == 'SP')]
# Out:
#       IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 4           15363        11           1   35108339
# 6           16100        13           2   25098349
# 7           15524        16           2   24009296
# 8           14264        18           2   27214915
# 9           14669        18           2   27214915
# ...           ...       ...         ...        ...
# 5260        20440      9312           2   35191577
# 5263        20444      9315           2   35007124
# 5264        20445      9316           2   35007524
# 5267        20449      9319           2   35007148
# 5269        20454      9321           2   25200801
#
#                                               Nome            CNPJ  \
# 4                             Colégio Santa Mônica  52566411000142
# 6                 Século Colégio E Curso - Estados  18595095000107
# 7                 Complexo Educacional Santo André  14875519000128
# 8                             Colégio São Jerônimo  69979326000109
# ...

# %%
dataframe.loc[0:5, ['TipoEscola']] = 1

# %%
dataframe.head()
# Out:
#    IDInscricao  IDEscola  TipoEscola  CodigoMEC  \
# 0        14833         4           1   23245980
# 1        15411         6           1   23564130
# 2        17568         7           1   33062706
# 3        14297         8           1   23025255
# 4        15363        11           1   35108339
#
#                                                 Nome            CNPJ  \
# 0                           Colégio Antares - Papicu   7250616000240
# 1  Alegria Do Saber Centro De Educacao Infantil E...  13207350000175
# 2                     Colégio Pedro Ii Campus Centro  42414284000706
# 3                             Colégio Luciano Feijão   9533217000212
# 4                               Colégio Santa Mônica  52566411000142
#
#   InscricaoEstadual                   Endereco Numero Complemento  ...  \
# 0               NaN   Rua Prof. Ocelo Pinheiro    101         NaN  ...
# 1               NaN          Rua 7 de Setembro    425         000  ...
# ...

# %%
dataframe.iloc[0:8, 5]
# Out:
# 0     7250616000240
# 1    13207350000175
# 2    42414284000706
# 3     9533217000212
# 4    52566411000142
# 5     1573657000100
# 6    18595095000107
# 7    14875519000128
# Name: CNPJ, dtype: int64
